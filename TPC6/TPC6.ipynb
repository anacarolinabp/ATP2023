# %% [markdown]
# ### TPC6: Análise de dados: doença cardíaca
#
# Descarregue o ficheiro de dados: [diabetes_prediction_dataset.csv](./datasets/diabetes_prediction_dataset.csv.zip).
#
# Encontra mais informação sobre este conjunto de dados [aqui](https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset).
#
# Crie um programa em Python, conjunto de funções, que responda às seguintes questões:
# * Crie uma função que lê a informação do ficheiro para um modelo, previamente pensado em memória;
# * Crie uma função que calcula a distribuição da doença por sexo (tenha atenção que indivíduos doentes e não doentes no dataset);
# * Crie uma função que calcula a distribuição da doença por escalões etários. Considere os seguintes escalões: [0-10], [11-24], [25-29], [30-34], [35-39], [40-44], ...
# * Crie uma função que calcula a distribuição da doença por níveis de glucose. Considere um nível igual a um intervalo de 10 unidades, comece no limite inferior e crie os níveis necessários até abranger o limite superior;
# * Crie uma função que imprime na forma de uma tabela uma distribuição;
# * Especifique um programa que ao executar apresenta as tabelas correspondentes às distribuições pedidas.

# %%
def carregar_dados (arquivo):
    dados =[]
    arquivo = open(arquivo, 'r')
    linhas = arquivo.readlines()
    arquivo.close()

    colunas = linhas[0].strip().split(" , ")
    for linha in linhas[1:]:
        valores = linha.strip().split(" , ")
        registro = {colunas[i] : valores[i] for i in range(len(colunas))}
        dados.append(registro)
    return dados

def distribuição_por_sexo (dados):
    distribuição = {}
    for registros in dados:
        sexo = registros["sexo"]
        if sexo in distribuição:
            distribuição[sexo] == distribuição[sexo] + 1
        else:
            distribuição()
    total = len(dados)
    for sexo, contagem in distribuição.items():
        distribuição[sexo] = contagem / total
    return distribuição

def distribuição_por_idade(dados):
    distribuição ={}
    for registro in dados:
        idade = int(registro["idade"])
        if idade < 11:
            grupo_idade ="0-10"
        else:
            grupo_idade =  f"{idade // 10 * 10 + 1} - {idade // 10 * 10 +10}"
        if grupo_idade in distribuição:
            distribuição[grupo_idade] = distribuição[grupo_idade] + 1
        else:
            distribuição[grupo_idade] = 1
    total = len(dados)
    for grupo, contagem in distribuição.items():
        distribuição[grupo] = contagem / total
    return distribuição

def distribuição_por_glucose(dados):
    distribuição = {}
    for registro in dados:
        glucose = int(registro ["glucose"])
        nível_glucose = glucose // 10 * 10 #arrendondamento do nivel de glucose
        if nível_glucose in distribuição:
            distribuição[nível_glucose] = distribuição[nível_glucose] +1
        else:
            distribuição[nível_glucose] = 1
    total = len(dados)
    for nível, contagem in distribuição.items():
        distribuição[nível] = contagem / total
    return distribuição

def print_distribuição(distribuição, título):
    print(título)
    for chave, valor in distribuição.items():
        print(F"{chave} : {valor}")

arquivo = "diabetes_prediction_dataset.csv"
dados = carregar_dados(arquivo)
distribuição_sexo = distribuição_por_sexo(dados)
print_distribuição(distribuição_sexo, " Distribuição por sexo")
distribuição_idade = distribuição_por_idade(dados)
print_distribuição(distribuição_idade, "Distribuição por escaloões etários")
distribuição_glucose = distribuição_por_glucose(dados)
print_distribuição(distribuição_glucose, "Distribuição por níveis de glucose")
