# %% [markdown]
# ### TPC7: Construir uma aplicação para manipular polinómios
#
# Depois da aula da semana passada, já tens algumas funções desenvolvidas que te irão ajudar a construir a aplicação que se descreve a seguir.
#
# * Aquecimento: Instancia os seguintes exemplos num ficheiro de texto com o formato definido na última aula
#     - `x^7 - 3.7x^4 + 5x^3 - 88`
#     - `2x^2 + 17`
#     - `7x^4 + 6x^3 - x^2 + 43`
#     - `x^4`
#     - `x^2`
#     - `x^3`
#
# * Desenvolve as seguintes funcionalidades que não foram trabalhadas na aula:
#     1. Define uma função que dado um polinómio calcula a sua derivada;
#     2. Define uma função que recebe dois polinómios `p1` e `p2` e calcula um novo polinómio correspondente à soma de `p1` e `p2`;
#     3. Define uma função que recebe um polinómio e o desenha num gráfico.
#
# * Num ficheiro Python, cria uma aplicação para manipular polinómios com as seguintes operações:
#     1. Criar um polinómio interativamente;
#     2. Ler uma lista de polinómios de um ficheiro;
#     3. Listar polinómios: mostra numa tabela os polinómios carregados em memória, adicionando um número de ordem a cada um;
#     4. Calcular o valor de um polinómio num ponto (usa o número de ordem para referenciar o polinómio);
#     5. Listar polinómios com grau: à listagem anterior, acrescenta mais uma coluna com o grau;
#     6. Maior grau: mostra o polinómio de maior grau e indica o seu número de ordem;
#     7. Derivada: mostra uma tabela com os polinómios e as respetivas derivadas;
#     8. Somar dois polinómios: indicando os seus números de ordem;
#     9. Gerar um gráfico para o polinómio;
#     10. Gravar num ficheiro os polinómios em memória;
#     0. Sair da aplicação

# %%
p1 = [(1, 7), (-3.7, 4), (5, 3), (-88,0)]
p2 = [(2,2), (17, 0)]
p3 = [(7, 4), (6,3), (-1,2), (43, 0)]
p4 = [(1, 4)]
p5 = [(1,2)]
p6 = [(1, 3)]

#1
def calculoDerivada(p):
    derivada = []
    for coef, grau in p:
        if grau > 0:
            derivada.append((coef * grau, grau - 1))
    return derivada

#2
def somarPol(p1, p2):
    res = []
    i, j = 0, 0
    while i < len(p1) and j < len(p2):
        coef1, grau1 = p1[i]
        coef2, grau2 = p2[j]
       
        if grau1 > grau2:
            res.append((coef1,grau1))
            i = i + 1
        elif grau1 < grau2:
            res.append((coef2, grau2))
            j = j +1
        else:
            res.appennd((coef1 +coef2, grau1))
            i = i + 1
            j = j + 1
#adicionar os termos restantes em p1 e p2 caso um polinomio tenha mais termos  do que o outro
    while i < len(p1):
        coef1, grau1 = p1[i]
        res.append((coef1, grau1)) 
    while j < len(p2):
        coef2, grau2 = p1[j]
        res.append((coef2, grau2)) 
    return res

#3
import matplotlib.pyplot as plt
def desenhaGrafico(p):
    x = []
    y = []

    for i in range(-20, 20):
        valorX = i
        valorY = 0
        for coef, grau in p:
            valorY= valorY + coef *(valorX ** grau)
        x.append(valorX)
        y.append(valorY)

    plt.plot(x, y)
    plt.title("Gráfico do polinómio")
    plt.xlabel("Abcissas")
    plt.ylabel("Ordenadas")
    plt.show()

# %%
def criaPolIn():
    resPol = []
    termos = int(input("quantos termos tem o polinomio"))
    i = 0
    while termos > 0:
        coef = float(input("introduz o coeficiente" + str(i))) 
        exp = int(input("introduz o termo do termo" + str(i)))
        resPol.append((coef, exp))
        termos = termos - 1
        i = i + 1
    return resPol

def calcPolinomio(p, x):
    res = 0
    for termo in p:
        coef, exp = termo
        res = res + (x**exp) * coef
    return res

def grauPolinomio(p):
    res = 0
    for monomio in p:
        coef, grau = monomio
        if grau > res:
            res = grau

    return res

def calculoDerivada(p):
    derivada = []
    for coef, grau in p:
        if grau > 0:
            derivada.append((coef * grau, grau - 1))
    return derivada

def somarPol(p1, p2):
    res = []
    i, j = 0, 0
    while i < len(p1) and j < len(p2):
        coef1, grau1 = p1[i]
        coef2, grau2 = p2[j]
       
        if grau1 > grau2:
            res.append((coef1,grau1))
            i = i + 1
        elif grau1 < grau2:
            res.append((coef2, grau2))
            j = j +1
        else:
            res.appennd((coef1 +coef2, grau1))
            i = i + 1
            j = j + 1
#adicionar os termos restantes em p1 e p2 caso um polinomio tenha mais termos  do que o outro
    while i < len(p1):
        coef1, grau1 = p1[i]
        res.append((coef1, grau1)) 
    while j < len(p2):
        coef2, grau2 = p1[j]
        res.append((coef2, grau2)) 
    return res

import matplotlib.pyplot as plt
def desenhaGrafico(p):
    x = []
    y = []

    for i in range(-20, 20):
        valorX = i
        valorY = 0
        for coef, grau in p:
            valorY= valorY + coef *(valorX ** grau)
        x.append(valorX)
        y.append(valorY)

    plt.plot(x, y)
    plt.title("Gráfico do polinómio")
    plt.xlabel("Abcissas")
    plt.ylabel("Ordenadas")
    plt.show()

def lerPolinomiosDeFicheiro(nome_do_ficheiro):
    polinomios = []
    with open(nome_do_ficheiro, 'r') as arquivo:
        for linha in arquivo:
            termos = linha.strip().split()
            polinomio = []
            for i in range(0, len(termos), 2):
                coef = float(termos[i])
                exp = int(termos[i + 1])
                polinomio.append((coef, exp))
            polinomios.append(polinomio)
    return polinomios

def gravarPolinomiosEmFicheiro(nome_do_ficheiro, polinomios):
        with open(nome_do_ficheiro, 'w') as arquivo:
            for polinomio in polinomios:
                termos = []
                for coef, exp in polinomio:
                    termos.extend([str(coef), str(exp)])
                linha = " ".join(termos)
                arquivo.write(f"{linha}\n")

def listarPolinomios(polinomios):
    for i, polinomio in enumerate(polinomios, start=1):
        print(f"Polinómio {i}: {polinomio}")

def listarPolinomiosComGrau(polinomios):
    for i, polinomio in enumerate(polinomios, start=1):
        grau = grauPolinomio(polinomio)
        print(f"Polinómio {i} (Grau {grau}): {polinomio}")
        def maiorGrau(polinomios):
    if not polinomios:
        print("Não há polinómios na lista.")
        return
        
def maiorGrau(polinomios):
    if not polinomios:
        print("Não há polinómios na lista.")
        return
    max_grau = -1
    polinomio_maior_grau = None

    for polinomio in polinomios:
        grau = grauPolinomio(polinomio)
        if grau > max_grau:
            max_grau = grau
            polinomio_maior_grau = polinomio

    numero_ordem = polinomios.index(polinomio_maior_grau) + 1
    print(f"Polinómio de Maior Grau (Grau {max_grau}) - Número de Ordem {numero_ordem}: {polinomio_maior_grau}")

def mostrarDerivadas(polinomios):
    for i, polinomio in enumerate(polinomios, start=1):
        derivada = calculoDerivada(polinomio)
        print(f"Polinómio {i} - Derivada: {derivada}")

def menu():
    polinomios = []

    while true:
        print("Operações disponíveis:")
        print("1. Criar um polinómio interativamente")
        print("2. Ler uma lista de polinómios de um ficheiro")
        print("3. Listar polinómios")
        print("4. Calcular o valor de um polinómio num ponto")
        print("5. Listar polinómioos com grau")
        print("6. Maior grau")
        print("7. Derivada")
        print("8. Somar dois polinómios")
        print(" 9. Gerar um gráfico para o polinómio")
        print("10. Gravar num ficheiro os polinómios em memória")
        print("0. Sair da aplicação")

        opção = int(input("escolha uma operação: "))
    
        if opção == 0:
            break 
        elif opção == 1:
            polinomio = criaPolIn()
            polinomios.append(polinomio)
        elif opção == 2:
            nome_do_ficheiro = input("Introduza o nome do ficheiro: ")
            polinomios.extend(lerPolinomiosDeFicheiro(nome_do_ficheiro))
        elif opção == 3:
            listarPolinomios(polinomios)
        elif opção == 4:
            numero_ordem = int(input("Digite o número de ordem do polinómio: "))
            x = float(input("Digite o valor de x: "))
            if 1 <= numero_ordem <= len(polinomios):
                polinomio = polinomios[numero_ordem - 1]
                resultado = calcPolinomio(polinomio, x)
                print(f"O valor do polinómio é: {resultado}")
            else:
                print("Número de ordem inválido.")
        elif opção == 5:
            listarPolinomiosComGrau(polinomios)
        elif opção == 6:
            maiorGrau(polinomios)
        elif opção == 7:
            mostrarDerivadas(polinomios)
        elif opção == 8:
            numero1 = int(input("Digite o número de ordem do primeiro polinómio: "))
            numero2 = int(input("Digite o número de ordem do segundo polinómio: "))
            if 1 <= numero1 <= len(polinomios) and 1 <= numero2 <= len(polinomios):
                polinomio1 = polinomios[numero1 - 1]
                polinomio2 = polinomios[numero2 - 1]
                resultado = somarPol(polinomio1, polinomio2)
                polinomios.append(resultado)
                print("Polinómio resultante adicionado com sucesso.")
            else:
                print("Número de ordem inválido.")
        elif opção == 9:
            numero_ordem = int(input("Digite o número de ordem do polinómio: "))
            if 1 <= numero_ordem <= len(polinomios):
                polinomio = polinomios[numero_ordem - 1]
                desenhaGrafico(polinomio)
            else:
                print("Número de ordem inválido.")
        elif opção == 10:
            nome_do_ficheiro = input("Digite o nome do ficheiro: ")
            gravarPolinomiosEmFicheiro(nome_do_ficheiro, polinomios)
        else:
            print("Opção inválida. Por favor, escolha uma operação válida.")
